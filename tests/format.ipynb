# %% [markdown]
# # test for jupyter notebook format
# print, error, and plot

# %%
# test print

print("Hello, World!")

# %%
# test error

1 / 0

# %%
import matplotlib.pyplot as plt

# test plot

plt.plot([1, 2, 3, 4, 5], [1, 4, 9, 16, 25])
plt.show()
