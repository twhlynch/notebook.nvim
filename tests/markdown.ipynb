# %% [markdown]
# # Text
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Pellentesque luctus
# pretium tincidunt. Ut quis lobortis nibh. Quisque eu nibh id ante congue
# commodo sed a sapien.

# %% [markdown]
# # Lists
#
# - first
# - second
# - third
#
# * first
# * second
# * third
#
# 1. first
# 2. second
# 3. third

# %% [markdown]
# # Code
#
# ```python
# def hello_world():
#     print("Hello World")
# ```

# %% [markdown]
# # links
#
# [example](https://example.com)

# %% [markdown]
# # Table
#
# | key | value |
# | --- | ----- |
# | 0   | zero  |
# | 1   | one   |
# | 2   | two   |

# %% [markdown]
# # Quote
#
# > This is a quote
